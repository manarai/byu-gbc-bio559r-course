# %% [markdown]
# # Hybridoma Cell Culture Analysis Exercise
# ## Systems Biology - Vaccine Production Optimization
#
# **Student Name:** _______________
# **Date:** _______________
#
# # Hybridoma Cell Culture Analysis - Student Exercise
# ## Finding the Best Treatment for Vaccine Production
#
# # Introduction and Motivation
#
# In the biotechnology industry, optimizing cell culture conditions is critical for maximizing both cell viability and product yield in large-scale biomanufacturing processes. Mouse hybridoma cells are a well-established production platform for monoclonal antibodies, and their performance is highly sensitive to nutrient availability, growth factors, and environmental cues. Suboptimal culture conditions can lead to nutrient depletion, waste metabolite accumulation, reduced viability, and ultimately lower antibody titers, all of which directly impact process economics and product quality. To address these challenges, systematic evaluation of culture supplements such as glucose, glutamine, serum, growth factors, and metabolic regulators provides a rational strategy for enhancing hybridoma productivity. This experiment is motivated by the need to generate quantitative insights into how different supplements influence cell density, viability, antibody production, and metabolic profiles. Such knowledge supports process development teams in the biotech sector by enabling data-driven decisions for media optimization, cost-effective scale-up, and regulatory-compliant biologics manufacturing.
#
# **Instructions:** Run each cell one by one and observe the results.
# Answer the questions at the end based on your analysis.
#
# ### What are Hybridoma Cells?
# Hybridoma cells are special cells created by fusing:
# - B cells (immune cells that make antibodies)
# - Immortal cancer cells (that can grow forever)
#
# Result: Cells that can produce antibodies (vaccines) indefinitely!
#
# ### Objective:
# Find which treatment makes the most antibodies for vaccine production.
#
# ### Data have been recorded on a table "hybridoma_culture_data.csv"
#
# ### Answer the following questions
#
# 1. Which treatment produced the MOST antibodies?
#
# 2. Which treatment had the BEST cell viability (healthiest cells)?
#
# 3. If you were the factory manager, which treatment would you choose for making vaccines?
#
# 4. What is the trade-off between making lots of antibodies vs keeping cells healthy?
#
# 5. Rank your TOP 3 treatments for vaccine production:
#
# 6. If you could test one more treatment, what would it be and why?
#
# 7. Based on the glucose consumption data, which treatment uses energy most efficiently?
#
# 8. What would you tell the company CEO about which treatment to use?

# %% [markdown]
# # Experimental Methods and Measurement Protocols
#
# ## Experimental Design
#
# ### Cell Line and Culture Conditions
#
# • Cell Line: Mouse hybridoma cells (fusion of B-lymphocytes and immortalized myeloma cells)
#
# • Base Medium: RPMI-1640 supplemented with 10% fetal bovine serum, 2 mM L-glutamine, 100 U/mL penicillin, and 100 μg/mL streptomycin
#
# • Culture Conditions: 37°C, 5% CO₂, humidified atmosphere
#
# • Initial Seeding Density: 2 × 10⁵ cells/mL in 250 mL shake flasks
#
# ### Treatment Groups
#
# 1. Control: Standard RPMI-1640 medium
#
# 2. Glucose Supplement: Base medium + 2 g/L additional glucose
#
# 3. Glutamine Supplement: Base medium + 4 mM additional L-glutamine
#
# 4. Serum Supplement: Base medium + 5% additional fetal bovine serum
#
# 5. IGF-1 Supplement: Base medium + 10 ng/mL insulin-like growth factor-1
#
# 6. Ascorbic Acid: Base medium + 50 μg/mL L-ascorbic acid
#
# 7. Sodium Butyrate: Base medium + 2 mM sodium butyrate
#
# ### Experimental Protocol
#
# • Duration: 168 hours (7 days)
#
# • Sampling: Every 24 hours
#
# • Replicates: 3 biological replicates per treatment
#
# • Sample Volume: 1 mL removed for analysis at each time point
#
# ### Measurement Methods and Instrumentation
#
# ### 1. Cell Density Measurement
#
# • Method: Automated cell counting using hemocytometer with trypan blue exclusion
#
# • Instrument: Countess II FL Automated Cell Counter (Thermo Fisher Scientific)
#
# • Procedure:
#
#     • Mix 10 μL cell suspension with 10 μL 0.4% trypan blue
#
#     • Load into counting chamber slide
#
#     • Automated counting of live cells (clear) and dead cells (blue)
#
# • Units: cells/mL
#
# • Accuracy: ±5% for concentrations >10⁴ cells/mL
#
# ### 2. Cell Viability Assessment
#
# • Method: Trypan blue exclusion assay
#
# • Principle: Live cells exclude trypan blue dye; dead cells take up the dye
#
# • Calculation: Viability (%) = (Live cells / Total cells) × 100
#
# • Instrument: Same as cell density measurement
#
# • Units: Percentage (%)
#
# ### 3. Antibody Concentration Analysis
#
# • Method: Enzyme-Linked Immunosorbent Assay (ELISA)
#
# • Instrument: SpectraMax M3 Multi-Mode Microplate Reader (Molecular Devices)
#
# • Procedure:
#
#     • Coat 96-well plates with capture antibody overnight at 4°C
#
#     • Block with 1% BSA for 1 hour at room temperature
#
#     • Add diluted culture supernatant samples (1:10 to 1:1000 dilutions)
#
#     • Incubate with detection antibody conjugated to HRP
#
#     • Develop with TMB substrate and read at 450 nm
#
# • Standard Curve: Purified antibody standards (0-500 mg/L)
#
# • Units: mg/L
#
# • Detection Limit: 5 mg/L
#
# • Precision: CV <10%
#
# ### 4. Glucose Concentration Measurement
#
# • Method: Enzymatic glucose assay (glucose oxidase method)
#
# •Instrument: YSI 2900D Biochemistry Analyzer (YSI Life Sciences)
#
# • Principle:
#
#     • Glucose + O₂ → Gluconic acid + H₂O₂ (glucose oxidase)
#
#     • H₂O₂ detection via platinum electrode
#
#
#
# • Sample Preparation: 25 μL culture supernatant, centrifuged to remove cells
#
# • Units: g/L
#
# • Range: 0.1-25 g/L
#
# • Accuracy: ±2%
#
# ### 5. Lactate Concentration Measurement
#
# • Method: Enzymatic lactate assay (lactate oxidase method)
#
# • Instrument: YSI 2900D Biochemistry Analyzer (YSI Life Sciences)
#
# • Principle:
#
#     • L-Lactate + O₂ → Pyruvate + H₂O₂ (lactate oxidase)
#
#     • H₂O₂ detection via platinum electrode
#
# • Sample Preparation: Same as glucose measurement
#
# • Units: g/L
#
# • Range: 0.1-15 g/L
#
# • Accuracy: ±2%
#
# ### Quality Control Measures
#
# ### Sample Handling
#
# • All samples processed within 2 hours of collection
#
# • Samples stored at 4°C if immediate analysis not possible
#
# • Cell-free supernatants obtained by centrifugation at 300×g for 5 minutes
#
# Calibration and Standards
#
# • Daily calibration of cell counter with standard beads
#
# • Fresh glucose and lactate standards prepared weekly
#
# • ELISA standard curves run in duplicate on each plate
#
# • Positive and negative controls included in each assay
#
# Data Validation
#
# • Outliers identified using Grubbs' test (α = 0.05)
#
# • Technical replicates performed for samples with CV >15%
#
# • Mass balance calculations performed for glucose consumption vs. lactate production
#
# ### Statistical Analysis
#
# • Data presented as mean ± standard deviation
#
# • Statistical significance determined by one-way ANOVA followed by Tukey's post-hoc test
#
# • p < 0.05 considered statistically significant
#
# • All analyses performed using Python (scipy.stats module)

# %% [markdown]
# ## # Step 1: Import the tools we need for analysis

# %%
import pandas as pd         # For manipulating table and data
import numpy as np   # For doing math on numbers
from scipy import stats     # For statistical anlaysis
import matplotlib.pyplot as plt # For ploting
import seaborn as sns          # For advance ploting

# Set up plotting style for better-looking graphs
plt.style.use('default')
sns.set_palette("husl")

# %% [markdown]
# ## # Step 2" Load the experimental data

# %%
data = pd.read_csv('hybridoma_culture_data.csv')

# %% [markdown]
# ## Step 3: Look at our data structure

# %%
print("What does our data look like?")
print("\nFirst 5 rows of data:")
print(data.head())
# Out:
# What does our data look like?
#
# First 5 rows of data:
#   Treatment  Replicate  Time_hours  Cell_density_per_mL  Viability_percent  \
# 0   Control          1           0         2.000000e+05          95.993428
# 1   Control          1          24         3.940126e+05          89.731693
# 2   Control          1          48         5.337755e+05          86.485120
# 3   Control          1          72         6.969058e+05          77.150164
# 4   Control          1          96         1.112437e+06          72.975393
#
#    Antibody_mg_per_L  Glucose_g_per_L  Lactate_g_per_L
# 0           0.000000         4.500000         0.064769
# 1           3.258640         3.830494         0.411496
# 2           8.514365         3.651775         0.448309
# 3          16.408969         3.424619         0.569115
# 4          46.525825         2.688373         0.912567

# %%
data
# Out:
#            Treatment  Replicate  Time_hours  Cell_density_per_mL  \
# 0            Control          1           0         2.000000e+05
# 1            Control          1          24         3.940126e+05
# 2            Control          1          48         5.337755e+05
# 3            Control          1          72         6.969058e+05
# 4            Control          1          96         1.112437e+06
# ..               ...        ...         ...                  ...
# 163  Sodium_butyrate          3          72         7.164628e+05
# 164  Sodium_butyrate          3          96         8.854676e+05
# 165  Sodium_butyrate          3         120         1.223969e+06
# 166  Sodium_butyrate          3         144         1.399153e+06
# 167  Sodium_butyrate          3         168         1.424360e+06
#
#      Viability_percent  Antibody_mg_per_L  Glucose_g_per_L  Lactate_g_per_L
# 0            95.993428           0.000000         4.500000         0.064769
# ...

# %%
print(f" The data has {len(data['Treatment'].unique())} different treatments")
print(f" The data has {len(data['Time_hours'].unique())} time point")
print(f" Each treatment has {len(data['Replicate'].unique())} number of replicate")
# Out:
#  The data has 7 different treatments
#  The data has 8 time point
#  Each treatment has 3 number of replicate

# %%
len(data['Treatment'].unique())
# Out:
# 7

# %%
print("What treatments did we test?")
treatments = data['Treatment'].unique()
for i, treatment in enumerate(treatments, 1):
    print(f"{i}. {treatment}")
# Out:
# What treatments did we test?
# 1. Control
# 2. Glucose_supplement
# 3. Glutamine_supplement
# 4. Serum_supplement
# 5. IGF1_supplement
# 6. Ascorbic_acid
# 7. Sodium_butyrate

# %% [markdown]
# ## Step 4: Check data quality

# %%
# Show basic statistics
print("Basic statistics for our measurements:")
print(data[['Cell_density_per_mL', 'Viability_percent', 'Antibody_mg_per_L']].describe())
# Out:
# Basic statistics for our measurements:
#        Cell_density_per_mL  Viability_percent  Antibody_mg_per_L
# count         1.680000e+02         168.000000         168.000000
# mean          1.358760e+06          80.167612          82.558206
# std           9.611580e+05          14.391933          90.866873
# min           2.000000e+05          25.637887           0.000000
# 25%           4.374021e+05          74.578855           9.223171
# 50%           1.172982e+06          83.591467          48.351642
# 75%           2.128597e+06          90.016248         137.021183
# max           3.773190e+06          98.264823         433.604322

# %%
data[['Cell_density_per_mL', 'Viability_percent', 'Antibody_mg_per_L']].describe()
# Out:
#        Cell_density_per_mL  Viability_percent  Antibody_mg_per_L
# count         1.680000e+02         168.000000         168.000000
# mean          1.358760e+06          80.167612          82.558206
# std           9.611580e+05          14.391933          90.866873
# min           2.000000e+05          25.637887           0.000000
# 25%           4.374021e+05          74.578855           9.223171
# 50%           1.172982e+06          83.591467          48.351642
# 75%           2.128597e+06          90.016248         137.021183
# max           3.773190e+06          98.264823         433.604322

# %% [markdown]
# ## Step 5: Create graphs to visualize our results

# %%
## Part 1: Visualizing Cell Growth Over Time
#Let's start by looking at how cell density changes over time for each treatment.

# Create a figure with subplots for better organization
fig, axes = plt.subplots(2, 2, figsize=(15, 12)) # 2 by 2 figures

# Plot 1: Cell density over time
ax1 = axes[0, 0]
# Group data by treatment and calculate mean values for each time point
for treatment in data['Treatment'].unique():
    # Filter data for current treatment
    treatment_data = data[data['Treatment'] == treatment]
    # Group by time and calculate mean cell density
    time_means = treatment_data.groupby('Time_hours')['Cell_density_per_mL'].mean()
    # Plot the line
    ax1.plot(time_means.index, time_means.values, marker='o', label=treatment, linewidth=2)

ax1.set_xlabel('Time (hours)')
ax1.set_ylabel('Cell Density (cells/mL)')
ax1.set_title('Cell Growth Curves by Treatment')
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax1.grid(True, alpha=0.3)

# %% [markdown]
# ## Step 6: Compare final results (at the end of experiment)

# %% [markdown]
# ## Step 7: Create bar charts to compare treatments

# %% [markdown]
# ## Step 8: Statistical analysis - Are the differences real?

# %% [markdown]
# ## Step 9: Compare each treatment to control
